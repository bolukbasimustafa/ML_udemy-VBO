# %% [markdown]
# # Basit Doğrusal Regresyon

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Modelleme

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
import pandas as pd
ad = pd.read_csv("Advertising.csv", usecols = [1,2,3,4]) # ilk sütuna indexs değerler gelince usecol ile istenilen columnlar alındı
df = ad.copy()
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
#df = df.iloc[:,1:len(df)]   # ilk sütuna index değerler gelince bu yöntemle ilk sütun dışındakiler alınır ve df e atanır

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.describe().T
# Out:
#            count      mean        std  min     25%     50%      75%    max
# TV         200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# radio      200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# newspaper  200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# sales      200.0   14.0225   5.217457  1.6  10.375   12.90   17.400   27.0

# %% [markdown]
# mean ve %50(median) değerlerinin birbirinden çokta farklı olmaması iyi. verinin dağılımı hakkında olumlu bilgi verir. mean ve median ın birbirinden uzak olması verinin dağılımının çarpık olabileceğini, birkaç tepeli dağılım olabileceğini gösterir

# %%
# df içinde null değer varmı
df.isnull().values.any()
# Out:
# False

# %%
df.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %% [markdown]
# * sales bağımlı değişkenimiz yani y; tv, radio ve newspaper reklamları ise bağımsız değişkenler.
# * ilk değerlendirme olarak tv reklamları ve sales arasında pozitif yönlü güçlü bir ilişki olduğunu görebiliyoruz. tv reklamları arttıkça sales artışı olabileceğini söyleyebiliriz. radio reklamları ve sales arasındada pozitif yönlü orta şiddetli bir ilişki olduğu görülüyor. newspaper reklamları ve sales arasında ise pozitif yönlü düşük bir ilişki olduğu gözlemleniyor
# * en anlamlı ve etki düzeyi yüksek değişkenin tv reklamları olduğu görülüyor
# * burada ayrıca radio ve tv arasında yüksek bir corelasyon olmaması model kurma sırasında radio değişkeninide kullanabileğimizi anlayabiliyoruz. tv ve radio arasında güçlü bir ilişki olmuş olsa y bağımlı değişkene olan etkilerinin birbirlerinden etkilendiklerini bu nedenle de modelde ikisinin birlikte kullanılmaması gerektiği yorumu çıkabilir. ilişkinin şideddtinin güçlü olmaması nedeniyle sales deki farkli bir varyasyonu radio reklamlarının açıklayabiliyor olabileceğini değerlendirebiliyoruz.

# %%
import seaborn as sns
sns.pairplot(df, kind  ="reg");

# %% [markdown]
# burdada tv reklamları ile sales arasındaki doğrusal pozitif yönlü güçlü ilişki doğrusal regresyon doğrusu ilede belli olmaktadır. Aynı şekilde radio reklamları ile sales arasındaki orta şeddetli pozitif yönlü ilişkide görülmektedir. newspaper reklamları ile sales arasındaki ilişkide eğimin iyice düştüğü görülmekte. buda ilişkinin şiddetinin azaldığını gösteriyor.

# %%
sns.jointplot(x = "TV", y = "sales", data = df, kind = "reg");

# %% [markdown]
# tek değişken olarak tv ve sales arasındaki ilişkiye baktığımızda ise sales in normal dağılım sergilediği görülüyor. tv ise iki tepeli bir görüntü sergiliyor. regresyon doğrusu ile ilgili yorumlar daha önce yapıldığı gibi

# %% [markdown]
# ## Statsmodels ile modelleme

# %%
import statsmodels.api as sm

# %%
X = df[["TV"]]     # basit doğrusal regresyon modelinde tek değişken olarak tv' yi X bağımsız değişkeni olarak alıyoruz
X[0:5]
# Out:
#       TV
# 0  230.1
# 1   44.5
# 2   17.2
# 3  151.5
# 4  180.8

# %%
X = sm.add_constant(X)    # tek değişkenli bir matrise 1 sabiti ekleyerek iki değişkenli matris yaparak matris 
                          # işlemlerinin yapılabilmesini sağlıyoruz. aşağıdaki matrise bakarak durumu görelim

# %%
X[0:5]
# Out:
#    const     TV
# 0    1.0  230.1
# 1    1.0   44.5
# 2    1.0   17.2
# 3    1.0  151.5
# 4    1.0  180.8

# %%
y = df["sales"]

# %%
y[0:5]
# Out:
# 0    22.1
# 1    10.4
# 2     9.3
# 3    18.5
# 4    12.9
# Name: sales, dtype: float64

# %% [markdown]
# ### model kurma için birinci yol

# %%
lm = sm.OLS(y,X)               # lm : lineer model, y bağımlı değişken, X bağımsız değişken, model kuruluyor

# %%
model = lm.fit()               # gercek model fit ediliyor

# %%
model.summary()                

# modelin çıktılarına ulaşılıyor. burdaki geniş çaplı çıktı ve istatistiksel testleri sklearn ile alamıyoruz, 
# bu nedenle bu tip doğrusal regresyon modelinde istatistiksel anlamdaki detaylı değerlere erişmek için statsmodels
# fonksiyonu kütüphanesi ile gerçekleştirebiliyoruz
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     312.1
# Date:                Fri, 16 Sep 2022   Prob (F-statistic):           1.47e-42
# Time:                        23:14:04   Log-Likelihood:                -519.05
# No. Observations:                 200   AIC:                             1042.
# Df Residuals:                     198   BIC:                             1049.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.0326      0.458     15.360      0.000       6.130       7.935
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Dep.Variable ile bağımlı değişken ifade ediliyor
# * MOdel ile Model OLS olarak belirtilmiş
# * Method ile Least Squares (en kucuk kareler) olarak belirtilmiş
#
# * R-squared: çıktının en önemli yanlarından biridir. bağımsız değişkenin bağımlı değişkendeki değişkenliği açıklama başarısıdır. Elimizdeki TV değişkeni sales değişkeninde yer alan değişkenliğin yaklaşık %60 (0.612) ını açıklayabilmektedir.
#
# * Adj. R-squared (Düzeltilmiş R-squared) : R-squared ile Adj. R-squared arasındaki fark şudur: R-squared fromulasyonu itibariyle modele ne kadar fazla değişken eklersek ekleyelim şişmeye meyillidir artacaktır. Dolayısıyla modelde ilgili ilgisiz anlamlı anlamsız değişken olması durumunda artacaktır. R-squared açıklanabilirlik oranıdır.  Dolayısıyla modelde ilgili ilgisiz anlamlı anlamsız değişken ekleyip R-squared in arttığını gördüğümüzde  iyi bir yolda olduğumuzu düşünebilirz. Bu durum çok yanıltıcı bir durumdur.  Adj. R-squared; R-squared in her parametre eklenmesine karşı duyarlılığı törpüleyen düzenleyen duyarlılığı daha az olan bir metriktir. Birden fazla değişken olduğunda Adj. R-squared değeri bizim için daha değerli ve düzgün bir değerdir.
#
# * F-statistic: Modelin anlamlılığının anlaşılması için kurulan test istatistiğidir. Kurulan model bize bazı tahminler verecek ve  belli bir tahmin başarısı olacaktır ama bu model anlamlımı sorsunu istatistiki olarak test edip modelin anlamlılığına yönelik yapılan F istatistiğidir.
#
# * Prob (F-statistic): Modelin anlamlılığına yönelik yapılan F istatistiğinin P-value değeridir. P-value ve F-statistic birlikte incelenerek anlamlılığı incelenir.
#
# * AIC ve BIC : Model karşılaştırma için kullanılan 2 istatistik değeridir. şuan ilgilenmiyoruz
#
# * No. Observations : Gözlem sayısı | Df Residuals : Serbestlik derecesi bunlarlada ilgilenmiyoruz

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * modelin en anlamlı kısmıdır.
#
# * const : Beta0, TV : Beta1  değeri olan sabit değişkenlerdir. coef parametre olarak ifade ettiğimiz katsayı değeridir. Model üzerinden hesaplanılan değrlerdir. std err ile standart hataları verilmiştir. Katsayıların anlamlı olup olmadıklarını anlamak için t istatistiği ve t istatistiğine ilişkin P-value (P>|t|) değerleri verilmiş. Burdan anlamlı olduğu anlaşışılıyormuş ama nasıl öğrenmek lazım. 0.025 ve 0.975 ilede katsayıların güven aralığı verilmiş.
#
# * burdan şöyle bir sonuc çıkıyor:  TV değişkenine ait 0.0475 katsayı değeri (t istatistiği ve buna bağlı P-value değerine göre) istatiksel olarak anlamlıdır ve bu katsayı değeri yine istatiksel olarak %95 güvenilirlikle 0.042 ve 0.053 aralığında yer alacaktır. Bu yorum değerli bir bilgidir. Buna bakarak bazı stratejiler belirlenebilir
#
# * const un katsayı değeri olan 7.0326 değeri eğrinin y eksenini kestiği değerdir. sales de beklenen ortalama değerdir. TV reklamlarının bir etkisi olmadığında zaten beklenen ortalama değerdir.
#
# * TV nin katsayı değeri olan 0.0475 ise TV reklam harcamalaraında 1 br lik artış olduğunda sales de ortalama beklenen artış miktarıdır olarak yorumlanır.

# %% [markdown]
# ### model kurma için ikinci yol

# %%
import statsmodels.formula.api as smf
lm = smf.ols("sales ~ TV", df)          # bağımlı ve bağımsız değişken isimleri ile yazılıyor
model = lm.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     312.1
# Date:                Fri, 16 Sep 2022   Prob (F-statistic):           1.47e-42
# Time:                        23:14:04   Log-Likelihood:                -519.05
# No. Observations:                 200   AIC:                             1042.
# Df Residuals:                     198   BIC:                             1049.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.0326      0.458     15.360      0.000       6.130       7.935
# ...

# %%
model.params           # modelin parametre değerleri. Beta0 ve Beta1 değerleri
# Out:
# Intercept    7.032594
# TV           0.047537
# dtype: float64

# %%
model.summary().tables[1]          # katsayılarla ilişkin değerlerin olduğu tables ın ilgili kısmını veriyor
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
model.conf_int()                   # katsayıların güven aralığı. yukarıdaki kısmın 0.025 ile 0.975 aralığı kısmını alır 
                                   # yani %95 güven aralığı
# Out:
#                   0         1
# Intercept  6.129719  7.935468
# TV         0.042231  0.052843

# %%
model.f_pvalue                    # sadece modelin anlamlılığına ilişkin istatistiklere pvalue ya ulaşmak için
# Out:
# 1.4673897001947095e-42

# %%
print("f_pvalue: ", "%.4f" % model.f_pvalue)        # p-value değerini e den kurtarmak için
# Out:
# f_pvalue:  0.0000

# %%
print("fvalue: ", "%.2f" % model.fvalue)            # f-statistic değerine ulaşmak için
# Out:
# fvalue:  312.14

# %%
print("tvalue: ", "%.2f" % model.tvalues[0:1])      # parametre anlamlılığına ilişkin değerlere ulaşmak için
# Out:
# tvalue:  15.36

# %%
model.mse_model      # (hata kareler ortalaması) modelin anlamlılığına ilişkin model değerlendirme istatistiklerine ulaşmak için
# Out:
# 3314.6181668686486

# %%
model.rsquared
# Out:
# 0.611875050850071

# %%
model.rsquared_adj
# Out:
# 0.6099148238341623

# %%
model.fittedvalues[0:5]    # modelin tahmin ettiği y değerlerine ulaşmak için
# Out:
# 0    17.970775
# 1     9.147974
# 2     7.850224
# 3    14.234395
# 4    15.627218
# dtype: float64

# %%
y[0:5]                     # gercek y değerleri
# Out:
# 0    22.1
# 1    10.4
# 2     9.3
# 3    18.5
# 4    12.9
# Name: sales, dtype: float64

# %%
print("Sales = " +  str("%.2f" % model.params[0]) + " + TV" + "*" + str("%.2f" % model.params[1]))

# basit şekilde model denklemini yazmak için. önemli bir husus interview sorusu
# Out:
# Sales = 7.03 + TV*0.05

# %%
# TV reklam harcamaları ile sales arasındaki basit regresyon doğrusunu grafikte görmek için

g = sns.regplot(df["TV"], df["sales"], ci=None, scatter_kws={'color':'r', 's':9})
g.set_title("Model Denklemi: Sales = 7.03 + TV*0.05")
g.set_ylabel("Satış Sayısı")
g.set_xlabel("TV Harcamaları")
import matplotlib.pyplot as plt
plt.xlim(-10,310)
plt.ylim(bottom=0);

# %% [markdown]
# ### sklearn ile model kurma

# %%
from sklearn.linear_model import LinearRegression

# %%
X = df[["TV"]]
y = df["sales"]
reg = LinearRegression()
model = reg.fit(X, y)
print(model.intercept_)               # B0 Katsayısı
print(model.coef_)                    # B1 katsayısı
# Out:
# 7.032593549127693
# [0.04753664]

# %%
model.score(X,y)          # r-squared
# Out:
# 0.611875050850071

# %%
model.predict(X)[0:10]    # modelde tahmin edilen y değerlerine ulaşmak için
# Out:
# array([17.97077451,  9.14797405,  7.85022376, 14.23439457, 15.62721814,
#         7.44616232,  9.76595037, 12.74649773,  7.44140866, 16.53041431])

# %% [markdown]
# ## Tahmin

# %% [markdown]
# Model denklemi:
#
# Sales = 7.03 + TV*0.04
#
# Örneğin 30 birim TV harcaması olduğunda satışların tahmini değeri ne olur?

# %%
7.03 + 30*0.04
# Out:
# 8.23

# %%
X = df[["TV"]]
y = df["sales"]
reg = LinearRegression()
model = reg.fit(X, y)

# %%
model.predict([[30]])            # modele TV reklam harcaması için değer girdiğimizde buna yönelik tahmin sonucu verir
# Out:
# array([8.45869276])

# %%
yeni_veri = [[5],[90],[200]]     # TV reklam harcamalrı için birden çok farklı değer için sonuçları görmek için

# %%
model.predict(yeni_veri)
# Out:
# array([ 7.27027675, 11.31089119, 16.53992164])

# %% [markdown]
# ## Artıklar ve Makine Öğrenmesindeki Önemi

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
lm = smf.ols("sales ~ TV", df)
model = lm.fit()

# %%
# hata kareler ortalaması
mse = mean_squared_error(y, model.fittedvalues)    # gerçek değerler (y) ile tahmin edilen değerler(model.fittedvalues) arasındaki farkların karelerinin toplamının ortalaması

# %%
mse
# Out:
# 10.512652915656759

# %%
# hata kareler ortalaması karekökü
import numpy as np
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 3.2423221486546887

# %%
reg.predict(X)[0:10]      # tahmin değerler
# Out:
# array([17.97077451,  9.14797405,  7.85022376, 14.23439457, 15.62721814,
#         7.44616232,  9.76595037, 12.74649773,  7.44140866, 16.53041431])

# %%
y[0:10]                   # gercek değerler
# Out:
# 0    22.1
# 1    10.4
# 2     9.3
# 3    18.5
# 4    12.9
# 5     7.2
# 6    11.8
# 7    13.2
# 8     4.8
# 9    10.6
# Name: sales, dtype: float64

# %%
k_t = pd.DataFrame({"gercek_y": y[0:10],
                   "tahmin_y": reg.predict(X)[0:10]})

# %%
k_t                       # karşılaştırma tablosu
# Out:
#    gercek_y   tahmin_y
# 0      22.1  17.970775
# 1      10.4   9.147974
# 2       9.3   7.850224
# 3      18.5  14.234395
# 4      12.9  15.627218
# 5       7.2   7.446162
# 6      11.8   9.765950
# 7      13.2  12.746498
# 8       4.8   7.441409
# 9      10.6  16.530414

# %%
k_t["hata"] = k_t["gercek_y"] - k_t["tahmin_y"]

# %%
k_t
# Out:
#    gercek_y   tahmin_y      hata
# 0      22.1  17.970775  4.129225
# 1      10.4   9.147974  1.252026
# 2       9.3   7.850224  1.449776
# 3      18.5  14.234395  4.265605
# 4      12.9  15.627218 -2.727218
# 5       7.2   7.446162 -0.246162
# 6      11.8   9.765950  2.034050
# 7      13.2  12.746498  0.453502
# 8       4.8   7.441409 -2.641409
# 9      10.6  16.530414 -5.930414

# %%
k_t["hata_kare"] = k_t["hata"]**2

# %%
k_t
# Out:
#    gercek_y   tahmin_y      hata  hata_kare
# 0      22.1  17.970775  4.129225  17.050503
# 1      10.4   9.147974  1.252026   1.567569
# 2       9.3   7.850224  1.449776   2.101851
# 3      18.5  14.234395  4.265605  18.195390
# 4      12.9  15.627218 -2.727218   7.437719
# 5       7.2   7.446162 -0.246162   0.060596
# 6      11.8   9.765950  2.034050   4.137358
# 7      13.2  12.746498  0.453502   0.205664
# 8       4.8   7.441409 -2.641409   6.977040
# 9      10.6  16.530414 -5.930414  35.169814

# %%
np.sum(k_t["hata_kare"])                # hata kareler toplamı SSE
# Out:
# 92.90350329638103

# %%
np.mean(k_t["hata_kare"])               # hata kareler ortalaması MSE
# Out:
# 9.290350329638105

# %%
np.sqrt(np.mean(k_t["hata_kare"]))      # hata kareler oratalaması karekökü RMSE
# Out:
# 3.048007599996776

# %%
model.resid[0:10]      # modelin artıkları görmek için, hatalar yukarıda hesaplamıştık
# Out:
# 0    4.129225
# 1    1.252026
# 2    1.449776
# 3    4.265605
# 4   -2.727218
# 5   -0.246162
# 6    2.034050
# 7    0.453502
# 8   -2.641409
# 9   -5.930414
# dtype: float64

# %%
plt.plot(model.resid);

# %% [markdown]
# # Çoklu Doğrusal Regresyon¶

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
ad = pd.read_csv("Advertising.csv", usecols = [1,2,3,4])
df = ad.copy()
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %% [markdown]
# ### test train grubunu oluşturma

# %%
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict

# %%
X = df.drop("sales", axis = 1)              # sales columnu drop edip sadece X değişkenleri alıyoruz
y = df["sales"]                             # y değişkeni alıyoruz sadece

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state= 42)

# %% [markdown]
# * test_size = 0.20 ile train %80, test %20 ayarlanıyor
# * random_state= 42 ile her üretmede farklı sonuçlar çıkmaması için kulanılıyor. (random.seed gibi sanırım)

# %%
X_train.shape
# Out:
# (160, 3)

# %%
y_train.shape
# Out:
# (160,)

# %%
X_test.shape
# Out:
# (40, 3)

# %%
y_test.shape
# Out:
# (40,)

# %%
training = df.copy()           # veri setinin ilk hali

# %%
training.shape
# Out:
# (200, 4)

# %% [markdown]
# ## Statsmodels ile model kurma

# %%
lm = sm.OLS(y_train, X_train)

# %%
model = lm.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared (uncentered):                   0.982
# Model:                            OLS   Adj. R-squared (uncentered):              0.982
# Method:                 Least Squares   F-statistic:                              2935.
# Date:                Fri, 16 Sep 2022   Prob (F-statistic):                   1.28e-137
# Time:                        23:14:05   Log-Likelihood:                         -336.65
# No. Observations:                 160   AIC:                                      679.3
# Df Residuals:                     157   BIC:                                      688.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
model.summary().tables[1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ## scikit-learn model

# %%
lm = LinearRegression()
model = lm.fit(X_train, y_train)

# %%
model.intercept_           # sabit değişken B0
# Out:
# 2.9790673381226256

# %%
model.coef_                # X değişkenlerin katsayıları
# Out:
# array([0.04472952, 0.18919505, 0.00276111])

# %% [markdown]
# ## Tahmin

# %% [markdown]
# Model denklemi:
#
# Sales = 2.97 + TV0.04 + radio0.18 + newspaper*0.002
#
# Örneğin 30 birim TV harcaması, 10 birim radio harcamasi, 40 birimde gazete harcaması olduğunda satışların tahmini değeri ne olur?

# %%
yeni_veri = [[30], [10],[40]]
yeni_veri = pd.DataFrame(yeni_veri).T

# %% [markdown]
# * burada bir fark bulunuyor buna dikkat etmek gerekir. basit doğrusal regresyonda bu tahmini yaparken tek değişken x olduğundan herbir değer için ayrı ayrı y değeri tahminde bulunmuştu.
# * burada ise çoklu doğrusal regresyonda modelimizde 3 farklı x değişkeni var. girilen değerler herbir değişken için alınacağından önce DataFrame dönüştürüyoruz ve modelin x değişkenleri için kullanabilmesini sağlıyoruz

# %%
model.predict(yeni_veri)
# Out:
# array([6.32334798])

# %% [markdown]
# ### tahmin başarısı değerlendirme

# %% [markdown]
# #### train hatamız

# %%
rmse = np.sqrt(mean_squared_error(y_train, model.predict(X_train)))

# y_train gerçek y değerleri
# model.predict(X_train) X_train değerleri kullanılarak üretilen y tahmin değerleri

# %%
rmse
# Out:
# 1.6447277656443373

# %% [markdown]
# #### test hatamız

# %%
rmse = np.sqrt(mean_squared_error(y_test, model.predict(X_test)))

# %%
rmse
# Out:
# 1.7815996615334502

# %% [markdown]
# ## Model Tuning / Model Doğrulama

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
X = df.drop('sales', axis=1)
y = df["sales"]
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.20, 
                                                    random_state=144)
lm = LinearRegression() 
model = lm.fit(X_train, y_train)

# %%
np.sqrt(mean_squared_error(y_train, model.predict(X_train)))         # MSE train grubu
# Out:
# 1.6748559274650712

# %%
np.sqrt(mean_squared_error(y_test, model.predict(X_test)))           # MSE test grubu
# Out:
# 1.6640263686701038

# %%
model.score(X_train, y_train)
# Out:
# 0.8971614078663419

# %% [markdown]
# * üstteki 4 kod bloğu için :
# * verinin tamamı train ve test olmak üzere farklı oranlarda (80-20 gibi) ikiye ayrılıyor. fakat burada bu iki grubun verinin hangi kısımlarından seçileceği önem kazanıyor. ilk kod satırındaki random_state argümanına farklı değerler girilirse train ve test grupları farklı şekillerde yani verinin farklı kısımlarından seçimiş olur. her deneme sonrası train ve test grubu için MSE değerlerinin değiştiğini gözlemliyoruz.
# * bu durumun önüne geçmek için cross validasyon işlemi yapılır

# %% [markdown]
# * aşağı kısım için :
# * cross_val_score ile rsquare değeri hesaplanıyor. burada cv = 10 ile 10 farklı rsquare hesaplanıyor ve mean ile ortalaması alınıyor.

# %%
cross_val_score(model, X, y, cv = 10, scoring = "r2")       # 10 farklı rsquared değeri bulunuyor
# Out:
# array([0.87302696, 0.8581613 , 0.92968723, 0.89013272, 0.93146498,
#        0.93138735, 0.7597901 , 0.91217097, 0.83891753, 0.92882311])

# %%
cross_val_score(model, X, y, cv = 10, scoring = "r2").mean()
# Out:
# 0.8853562237979616

# %% [markdown]
# * 10 farklı rsquare değerinin ortalaması alınarak modelimiz için daha güvenilir ve doğrulanmış rsquare değeri bulunmuş olur

# %%
cross_val_score(model, X_train, y_train, cv = 10, scoring = "r2").mean()   

# train grubu için bulduğumuz valide edilmiş yani daha güvenilir rsquare değerini yukarıdaki model.score(X_train, y_train) ile karşılaştıralım
# Out:
# 0.8733783298422939

# %%
np.sqrt(-cross_val_score(model, 
                X_train, 
                y_train, 
                cv = 10, 
                scoring = "neg_mean_squared_error"))
# Out:
# array([1.94167741, 1.17857794, 1.14676306, 1.82238742, 2.97070189,
#        1.5424871 , 1.51235118, 1.02817521, 1.73070108, 1.77552332])

# %% [markdown]
# * validasyon ile 10 farklı MSE değeri buluyoruz
# * aşağıda ise ortalaması alınarak valide edilmiş doğrulanmış daha güvenilir MSE train bulunuyor.

# %%
np.sqrt(-cross_val_score(model, 
                X_train, 
                y_train, 
                cv = 10, 
                scoring = "neg_mean_squared_error")).mean()
# Out:
# 1.6649345607872934

# %%
np.sqrt(-cross_val_score(model, 
                X_test, 
                y_test, 
                cv = 10, 
                scoring = "neg_mean_squared_error"))
# Out:
# array([1.00960622, 1.00246182, 2.57280082, 1.73376861, 1.58098281,
#        2.4846819 , 2.31458394, 1.5746411 , 1.81611569, 1.31028205])

# %%
np.sqrt(-cross_val_score(model, 
                X_test, 
                y_test, 
                cv = 10, 
                scoring = "neg_mean_squared_error")).mean()
# Out:
# 1.7399924960346649

# %% [markdown]
# # PCR Model

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * gerçek hayat problemlerinin çoğunda üzerinde çalıştığımız veri setinin bağımsız değişkenleri birbirleri ile yüksek korelasyona sahip olabiliyor. Bu durum benzer tahminsel bilgileri barındırdıkları anlamına geliyor. Değişkenler arasında yüksek korelasyon olması çoklu doğrusal bağlantı probelimi adı verilen probleme neden oluyor. Bu prblem olunca EKK denilen en küçük kareler yöntemiyle bir tahmin işlemi parametrelere ulaşma işlemi yapmıştık . Çoklu doğrusal bağlantı probelimi  tahmincilerin yani katsayıların varyansını arttırmakta ve yanlılık oluşturmakta.
# * PCA (principal component analyse) Temel bileşen analizi : Elimizde P adet değişken olduğunda bu P adet değişkenin içerdiği bilginin yüksek bir kısmını ondan daha az sayıda bir değişken yani bileşen ile ifade etme fikrine dayanır.
# * Örneğin elimizde 100 değişken olsun ve bu 100 değişkenin içerdiği bir bilgi var. Bu bilgiyi daha az değişkenle maksimum ifade temeye çalışma şeklidir. 100 değişkenin taşıdığı bilgiyi bir miktar bilgi kaybını göze alarak 2 yada 3 bileşene indirgediğimde boyut indirgemesi yapmış oluyoruz. Bu analiz sonrası ortaya çıkan değişkenler birbirinden bağımsız oluyor yani corelasyonları olmuyor. Çoklu doğrusal bağlantı probelimi ortadan kalkmış olyor.
# * PCA sonrası ortaya çıkan 2, 3 yada daha fazla değişkene bir regresyon modeli uygulanmasına PCR (Principal Component Regression) Temel Bileşen Regresyonu deniyor.

# %%
import pandas as pd
import numpy as np
hit = pd.read_csv("Hitters.csv")
df = hit.copy()
df = df.dropna()
df.head()
# Out:
#    AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  CRuns  \
# 1    315    81      7    24   38     39     14    3449    835      69    321
# 2    479   130     18    66   72     76      3    1624    457      63    224
# 3    496   141     20    65   78     37     11    5628   1575     225    828
# 4    321    87     10    39   42     30      2     396    101      12     48
# 5    594   169      4    74   51     35     11    4408   1133      19    501
#
#    CRBI  CWalks League Division  PutOuts  Assists  Errors  Salary NewLeague
# 1   414     375      N        W      632       43      10   475.0         N
# 2   266     263      A        W      880       82      14   480.0         A
# 3   838     354      N        E      200       11       3   500.0         N
# 4    46      33      N        E      805       40       4    91.5         N
# 5   336     194      A        W      282      421      25   750.0         A

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 263 entries, 1 to 321
# Data columns (total 20 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   AtBat      263 non-null    int64
#  1   Hits       263 non-null    int64
#  2   HmRun      263 non-null    int64
#  3   Runs       263 non-null    int64
#  4   RBI        263 non-null    int64
#  5   Walks      263 non-null    int64
#  6   Years      263 non-null    int64
#  7   CAtBat     263 non-null    int64
#  8   CHits      263 non-null    int64
#  9   CHmRun     263 non-null    int64
#  10  CRuns      263 non-null    int64
#  11  CRBI       263 non-null    int64
#  12  CWalks     263 non-null    int64
#  13  League     263 non-null    object
#  14  Division   263 non-null    object
#  15  PutOuts    263 non-null    int64
#  16  Assists    263 non-null    int64
#  17  Errors     263 non-null    int64
#  18  Salary     263 non-null    float64
#  19  NewLeague  263 non-null    object
# ...

# %%
df.describe().T
# Out:
#          count         mean          std   min    25%     50%     75%      max
# AtBat    263.0   403.642586   147.307209  19.0  282.5   413.0   526.0    687.0
# Hits     263.0   107.828897    45.125326   1.0   71.5   103.0   141.5    238.0
# HmRun    263.0    11.619772     8.757108   0.0    5.0     9.0    18.0     40.0
# Runs     263.0    54.745247    25.539816   0.0   33.5    52.0    73.0    130.0
# RBI      263.0    51.486692    25.882714   0.0   30.0    47.0    71.0    121.0
# Walks    263.0    41.114068    21.718056   0.0   23.0    37.0    57.0    105.0
# Years    263.0     7.311787     4.793616   1.0    4.0     6.0    10.0     24.0
# CAtBat   263.0  2657.543726  2286.582929  19.0  842.5  1931.0  3890.5  14053.0
# CHits    263.0   722.186312   648.199644   4.0  212.0   516.0  1054.0   4256.0
# CHmRun   263.0    69.239544    82.197581   0.0   15.0    40.0    92.5    548.0
# CRuns    263.0   361.220532   331.198571   2.0  105.5   250.0   497.5   2165.0
# ...

# %%
dms = pd.get_dummies(df[['League', 'Division', 'NewLeague']])     # kategorik değişkenler için get dummies yapalım
dms.head()
# Out:
#    League_A  League_N  Division_E  Division_W  NewLeague_A  NewLeague_N
# 1         0         1           0           1            0            1
# 2         1         0           0           1            1            0
# 3         0         1           1           0            0            1
# 4         0         1           1           0            0            1
# 5         1         0           0           1            1            0

# %% [markdown]
# * yukarıda görüldüğü gibi League_A ile League_N aynı değeri ifade ediyor. tek sütunla ifade edilebir bu değişken durumu. diğer sütunlar içinde geçerli bu durum

# %%
y = df["Salary"]

# %%
# bağımlı değişken ve kategorik değişkenleri çıkararak yeni bir DataFrame oluşturalım
X_ = df.drop(["Salary","League","Division","NewLeague"], axis = 1).astype("float64")

# %%
X_.head()
# Out:
#    AtBat   Hits  HmRun  Runs   RBI  Walks  Years  CAtBat   CHits  CHmRun  \
# 1  315.0   81.0    7.0  24.0  38.0   39.0   14.0  3449.0   835.0    69.0
# 2  479.0  130.0   18.0  66.0  72.0   76.0    3.0  1624.0   457.0    63.0
# 3  496.0  141.0   20.0  65.0  78.0   37.0   11.0  5628.0  1575.0   225.0
# 4  321.0   87.0   10.0  39.0  42.0   30.0    2.0   396.0   101.0    12.0
# 5  594.0  169.0    4.0  74.0  51.0   35.0   11.0  4408.0  1133.0    19.0
#
#    CRuns   CRBI  CWalks  PutOuts  Assists  Errors
# 1  321.0  414.0   375.0    632.0     43.0    10.0
# 2  224.0  266.0   263.0    880.0     82.0    14.0
# 3  828.0  838.0   354.0    200.0     11.0     3.0
# 4   48.0   46.0    33.0    805.0     40.0     4.0
# 5  501.0  336.0   194.0    282.0    421.0    25.0

# %% [markdown]
# * aşağıda concat metodu ile bağımsız değişkenleri bir araya getirerek yeni bir DataFrame oluşturalım
# * dummy değişken tuzağından kurtulmak için League_A ile League_N, Division_E ile Division_W, NewLeague_A ile NewLeague_N den birini alarak concat yapıyoruz

# %%
X = pd.concat([X_, dms[["League_N", "Division_W","NewLeague_N"]]], axis = 1)
X.head()
# Out:
#    AtBat   Hits  HmRun  Runs   RBI  Walks  Years  CAtBat   CHits  CHmRun  \
# 1  315.0   81.0    7.0  24.0  38.0   39.0   14.0  3449.0   835.0    69.0
# 2  479.0  130.0   18.0  66.0  72.0   76.0    3.0  1624.0   457.0    63.0
# 3  496.0  141.0   20.0  65.0  78.0   37.0   11.0  5628.0  1575.0   225.0
# 4  321.0   87.0   10.0  39.0  42.0   30.0    2.0   396.0   101.0    12.0
# 5  594.0  169.0    4.0  74.0  51.0   35.0   11.0  4408.0  1133.0    19.0
#
#    CRuns   CRBI  CWalks  PutOuts  Assists  Errors  League_N  Division_W  \
# 1  321.0  414.0   375.0    632.0     43.0    10.0         1           1
# 2  224.0  266.0   263.0    880.0     82.0    14.0         0           1
# 3  828.0  838.0   354.0    200.0     11.0     3.0         1           0
# 4   48.0   46.0    33.0    805.0     40.0     4.0         1           0
# 5  501.0  336.0   194.0    282.0    421.0    25.0         0           1
#
#    NewLeague_N
# 1            1
# 2            0
# 3            1
# 4            1
# ...

# %% [markdown]
# ### train ve test olarak ayırma

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.25, 
                                                    random_state=42)

print("X_train", X_train.shape)

print("y_train",y_train.shape)

print("X_test",X_test.shape)

print("y_test",y_test.shape)

training = df.copy()

print("training", training.shape)
# Out:
# X_train (197, 19)
# y_train (197,)
# X_test (66, 19)
# y_test (66,)
# training (263, 20)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale 
pca = PCA()

# %%
X_reduced_train = pca.fit_transform(scale(X_train))

# %%
X_reduced_train[0:1,:]
# Out:
# array([[-2.49569913e+00, -3.37762397e-01,  7.06391950e-01,
#         -1.32791025e+00, -8.21824333e-01, -6.62790677e-01,
#         -6.56764789e-01,  3.68093279e-02, -2.03665105e-01,
#          1.76134815e-01, -9.20131987e-02,  2.40129020e-01,
#         -3.60473661e-03, -3.41246327e-02,  4.32799605e-02,
#          1.02996923e-01,  3.70733348e-03,  1.37933445e-03,
#         -6.63814471e-03]])

# %%
np.cumsum(np.round(pca.explained_variance_ratio_, decimals = 4)*100)[0:5]
# Out:
# array([38.18, 59.88, 70.88, 78.88, 84.18])

# %%
lm = LinearRegression()

# %%
pcr_model = lm.fit(X_reduced_train, y_train)

# %%
pcr_model.intercept_
# Out:
# 543.4834416243655

# %%
pcr_model.coef_
# Out:
# array([ 111.13977427,  -29.34209502,   26.29799759,  -38.47549852,
#         -56.9200785 ,   54.44779423,   40.77493384,  -23.72746012,
#           9.31198164,   13.02031672,   45.58357748,   31.97791627,
#          18.93930958, -115.60940171,   24.00382778,  415.70806202,
#        -449.51779543,  563.07375399,  302.53718462])

# %% [markdown]
# ## Tahmin

# %%
y_pred = pcr_model.predict(X_reduced_train)

# %%
y_pred[0:5]
# Out:
# array([377.44484744, 802.19452124, 495.60987745, 112.53177731,
#        426.21613066])

# %%
np.sqrt(mean_squared_error(y_train, y_pred))
# Out:
# 289.32928255649756

# %%
df["Salary"].mean()
# Out:
# 535.9258821292775

# %%
r2_score(y_train, y_pred)
# Out:
# 0.577007525041018

# %%
pca2 = PCA()

# %%
X_reduced_test = pca2.fit_transform(scale(X_test))

# %%
y_pred = pcr_model.predict(X_reduced_test)

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 405.1575364149967

# %% [markdown]
# ## Model Tuning

# %%
lm = LinearRegression()
pcr_model = lm.fit(X_reduced_train[:,0:10], y_train)
y_pred = pcr_model.predict(X_reduced_test[:,0:10])
print(np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# 390.79142556822245

# %%
from sklearn import model_selection

# %%
cv_10 = model_selection.KFold(n_splits = 10,
                             shuffle = True,
                             random_state = 1)

# %%
lm = LinearRegression()

# %%
RMSE = []

# %%
for i in np.arange(1, X_reduced_train.shape[1] + 1):
    
    score = np.sqrt(-1*model_selection.cross_val_score(lm, 
                                                       X_reduced_train[:,:i], 
                                                       y_train.ravel(), 
                                                       cv=cv_10, 
                                                       scoring='neg_mean_squared_error').mean())
    RMSE.append(score)

# %%
plt.plot(RMSE, '-v')
plt.xlabel('Bileşen Sayısı')
plt.ylabel('RMSE')
plt.title('Maaş Tahmin Modeli İçin PCR Model Tuning');

# %%
lm = LinearRegression()

# %%
pcr_model = lm.fit(X_reduced_train[:,0:6], y_train)

# %%
y_pred = pcr_model.predict(X_reduced_train[:,0:6])

# %%
print(np.sqrt(mean_squared_error(y_train, y_pred)))
# Out:
# 308.8265983094501

# %%
y_pred = pcr_model.predict(X_reduced_test[:,0:6])

# %%
print(np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# 393.1198700096224

# %% [markdown]
# # PLS

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * bağımsız değişkenlerin kombinasyonu üzerinden bağımlı değişken açıklanmaya çalışılır.
# * boyut indirgeme yaklaşımında P adet değişkenin taşıdığı bilgiyi ondan daha az sayıda C değişken ile ifade etmeye çalışma

# %% [markdown]
# ### PLS - Kısmi En Küçük Kareler Regresyonu
#
# * Çok boyutluluk laneti p > n 2 ne çözüm sunar
# * Çoklu doğrusal bağlantı problemine çözüm sunar
# * PLS de PCR gibi bağımsız değişkenlerin doğrusal kombinasyonlarını bulur. Bu doğrusal kombinasyonlar bileşen yada latent değişken olarak adlandırılır.
# * PLS NIPALS isimli algoritmanın özel bir halidir, iteratif olarak bağımlı değişken ile yüksek korelasyona sahip değişkenler arasındaki gizil (latent) ilişkiyi bulmaya çalışır. Bu durum PLS ile PCR ı ayıran noktadır.
#
# ### PCR vs PLS
# * PCR da doğrusal kombinasyonlar yani bileşenler bağımsız değişken uzayındaki değişkenliği maksimum şekilde özetleyecek şekilde oluşturulur. BU durum bağımlı değişkeni açıklama yeteneği olmamasına sepep olmakta.
# * PLS te ise bileşenler bağımlı değişken ile kovaryansı maksimum şekild özetleyecek şekilde oluşturulur.
# * PCR bağımsız değişkenlerin kendi arasında PLS ise bağımlı değişkene odaklı bir şekilde bu bileşenleri oluşturma işlemi yapıyor.
# * PLS ve PCR da boyut indirgemesi yapılıyor. PLS te boyut indirgeme bağımlı değişken odağında yapılıyor bu nedenle gözetimli boyut indirgeme prosedürü olarak, PCR da ise bağımlı değikenle bir ilişki olmaksızın  bağımsız değişkenleri kendi içinde değerlendirdiğimizden dolayı gözetimsiz boyut indirgeme prosedürü olarak görülebilir.
# * iki yöntemde de bir tuning parametresi vardır ve oda bilşene sayısıdır. Optimum bileşen sayısını belirlemek için Cross Validation kullanılır.

# %% [markdown]
# ## Model

# %%
hit = pd.read_csv("Hitters.csv")
df = hit.copy()
df = df.dropna()
ms = pd.get_dummies(df[['League', 'Division', 'NewLeague']])
y = df["Salary"]
X_ = df.drop(['Salary', 'League', 'Division', 'NewLeague'], axis=1).astype('float64')
X = pd.concat([X_, dms[['League_N', 'Division_W', 'NewLeague_N']]], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
from sklearn.cross_decomposition import PLSRegression, PLSSVD

# %%
# model kurma
pls_model = PLSRegression().fit(X_train, y_train)

# %%
# katsayılara ulaşma (modelin değişken sayısı kadar katsayısı var)
pls_model.coef_
# Out:
# array([[ 35.32916493],
#        [ 48.83425857],
#        [ 18.50240933],
#        [ 39.28117603],
#        [ 30.59952998],
#        [ 40.03398345],
#        [ 16.85990516],
#        [ 28.22289896],
#        [ 32.73784993],
#        [ 22.00875744],
#        [ 33.60903032],
#        [ 30.39402522],
#        [ 25.73279799],
#        [ 54.98835148],
#        [  6.56590871],
#        [ -0.90894359],
#        [ 17.60903423],
#        [-37.24246339],
#        [ 14.69680385]])

# %%
# boyut indirgeyerek model kurma
pls_model = PLSRegression(n_components = 2).fit(X_train, y_train)

# %%
# katsayılara ulaşma (modelin değişken sayısı kadar katsayısı var)
pls_model.coef_
# Out:
# array([[ 35.32916493],
#        [ 48.83425857],
#        [ 18.50240933],
#        [ 39.28117603],
#        [ 30.59952998],
#        [ 40.03398345],
#        [ 16.85990516],
#        [ 28.22289896],
#        [ 32.73784993],
#        [ 22.00875744],
#        [ 33.60903032],
#        [ 30.39402522],
#        [ 25.73279799],
#        [ 54.98835148],
#        [  6.56590871],
#        [ -0.90894359],
#        [ 17.60903423],
#        [-37.24246339],
#        [ 14.69680385]])

# %% [markdown]
# * Boyut indirgeme işleminde kuracak olduğumuz ve tahmin üretmesini beklediğimiz model sözkonusu olduğunda ana veri setimizde 10 değişken varsa bu değişkenlerin hepsinden kurtulmuyoruz. Yeni bir gözlem birimi geldiğinde verinin iki bileşene indirgenmiş olmasının sorun olacak olması nedeniyle, yeni gözlem biriminin veri setinde ilk haliyle kaç değişken varsa okadar gözlem değeri göndermesi gerekir. Yani 10 tane değişken varsa 10 tane değişken değeri göndermeli. Dolayısıyla veri seti bize bu gözlem değerlerini gönderdiğinde biz yukarıdaki katsayılara ile çarpıp burdan çıkan tahmin değerinin sonuç olarak alırız. BU nedenle PCR ve PLS katsayıları incelediğimizde bunların değişken sayısı kadar çıkmasını sağlarız.
# * Modelleme işleminin yapılması için bileşen sayısının ayarlanması ise farklı bir işlemdir. Biz bileşen sayısını ayarlayarak model kurma sürecinde bazı problemlerden kurtuluyoruz ve nihayetinde kurmuş olduğumuz  modelin tahmin modeli olarak kullanılması süreci söz konusu olduğunda elimizde veri setinde yer alan değişken kadar katsayı olması durumu söz konusu olur. Bir değişkenin, gözlemin  bağımsız değişken değerleri modele gönderildiğinde bu katsayıların bir doğrusal kombinasyonu işlemine tabi tutulup bu şekilde bir tahmin değeri oluşturması sağlanıyor.

# %% [markdown]
# ## Tahmin

# %%
X_train.head()
# Out:
#      AtBat   Hits  HmRun  Runs   RBI  Walks  Years  CAtBat   CHits  CHmRun  \
# 183  328.0   91.0   12.0  51.0  43.0   33.0    2.0   342.0    94.0    12.0
# 229  514.0  144.0    0.0  67.0  54.0   79.0    9.0  4739.0  1169.0    13.0
# 286  593.0  152.0   23.0  69.0  75.0   53.0    6.0  2765.0   686.0   133.0
# 102  233.0   49.0    2.0  41.0  23.0   18.0    8.0  1350.0   336.0     7.0
# 153  341.0   95.0    6.0  48.0  42.0   20.0   10.0  2964.0   808.0    81.0
#
#      CRuns   CRBI  CWalks  PutOuts  Assists  Errors  League_N  Division_W  \
# 183   51.0   44.0    33.0    145.0     59.0     8.0         1           0
# 229  583.0  374.0   528.0    229.0    453.0    15.0         1           0
# 286  369.0  384.0   321.0    315.0     10.0     6.0         0           1
# 102  166.0  122.0   106.0    102.0    132.0    10.0         0           0
# 153  379.0  428.0   221.0    158.0      4.0     5.0         1           1
#
#      NewLeague_N
# 183            1
# 229            1
# ...

# %%
pls_model
# Out:
# PLSRegression()

# %%
pls_model.predict(X_train)[0:10]            # tahmin değerleri
# Out:
# array([[344.91941493],
#        [848.87070769],
#        [692.93622642],
#        [185.56577984],
#        [435.49196077],
#        [987.49530026],
#        [120.63097106],
#        [289.9263406 ],
#        [663.41886918],
#        [817.90486641]])

# %%
y_pred = pls_model.predict(X_train)

# %%
np.sqrt(mean_squared_error(y_train, y_pred))      # train hatası MSE
# Out:
# 310.1167593109696

# %%
r2_score(y_train, y_pred)                         # rsquare
# Out:
# 0.5140424486535482

# %%
y_pred = pls_model.predict(X_test)                # test grubundaki X değerleri ile tahmin edilen y değerleri

# %%
np.sqrt(mean_squared_error(y_test, y_pred))       # test hatası MSE
# Out:
# 398.09956327448526

# %% [markdown]
# ## Model Tuning

# %% [markdown]
# * burada değişken sayısının optimum değerini bulmaya çalışıyoruz

# %%
# CV
cv_10 = model_selection.KFold(n_splits=10, shuffle=True, random_state=1)


#Hata hesaplamak için döngü
RMSE = []

for i in np.arange(1, X_train.shape[1] + 1):
    pls = PLSRegression(n_components=i)
    score = np.sqrt(-1*cross_val_score(pls, X_train, y_train, cv=cv_10, scoring='neg_mean_squared_error').mean())
    RMSE.append(score)

#Sonuçların Görselleştirilmesi
plt.plot(np.arange(1, X_train.shape[1] + 1), np.array(RMSE), '-v', c = "r")
plt.xlabel('Bileşen Sayısı')
plt.ylabel('RMSE')
plt.title('Salary');

# %% [markdown]
# * RMSE nin en küçük değeri alması için bileşen sayısını 2 olarak tespit ediyoruz

# %%
# bileşen sayısı 2 olarak modeli son olarak fit ediyoruz

# %%
pls_model = PLSRegression(n_components = 2).fit(X_train, y_train)

# %%
y_pred = pls_model.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 398.09956327448526

# %% [markdown]
# # Ridge Regresyon

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * problem burada aynı aykırı gözlemlere duyarlı olması varsayım bozulumları gibi problemler ile bu doğrusal regresyon modelinin kabiliyetlerini kullanarak daha ileri ve başarılı bir düzeye nasıl getiririz çabası onucu ortaya çıkan modelleme türüdür. .

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * L2 : düzenlelileştirme yöntemi olarak ifade ediliyor. her SSE ile elde edilen katsayılara ceza uygulaması yapılır. lambda ile verilecek cezayı bazı yöntemlerle optimize ederek ayarlama imkanına sahip oluyoruz.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Model

# %%
# train / test grubu ayırma
hit = pd.read_csv("Hitters.csv")
df = hit.copy()
df = df.dropna()
ms = pd.get_dummies(df[['League', 'Division', 'NewLeague']])
y = df["Salary"]
X_ = df.drop(['Salary', 'League', 'Division', 'NewLeague'], axis=1).astype('float64')
X = pd.concat([X_, dms[['League_N', 'Division_W', 'NewLeague_N']]], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.25, 
                                                    random_state=42)

# %%
from sklearn.linear_model import Ridge

# %%
# model kurma fit etme
ridge_model = Ridge(alpha = 0.1).fit(X_train, y_train)   # alpha parametresi lambda yı ifade eder

# %%
ridge_model
# Out:
# Ridge(alpha=0.1)

# %%
# katsayılar
ridge_model.coef_
# Out:
# array([ -1.77435737,   8.80240528,   7.29595605,  -3.33257639,
#         -2.08316481,   5.42531283,   7.58514945,  -0.13752764,
#         -0.20779701,  -0.60361067,   1.7927957 ,   0.72866408,
#         -0.68710375,   0.26153564,   0.26888652,  -0.52674278,
#        112.14640272, -99.80997876, -48.07152768])

# %%
# aşağıdaki döngüde kullanılacak lambda değerleri
10**np.linspace(10,-2,100)*0.5
# Out:
# array([5.00000000e+09, 3.78231664e+09, 2.86118383e+09, 2.16438064e+09,
#        1.63727458e+09, 1.23853818e+09, 9.36908711e+08, 7.08737081e+08,
#        5.36133611e+08, 4.05565415e+08, 3.06795364e+08, 2.32079442e+08,
#        1.75559587e+08, 1.32804389e+08, 1.00461650e+08, 7.59955541e+07,
#        5.74878498e+07, 4.34874501e+07, 3.28966612e+07, 2.48851178e+07,
#        1.88246790e+07, 1.42401793e+07, 1.07721735e+07, 8.14875417e+06,
#        6.16423370e+06, 4.66301673e+06, 3.52740116e+06, 2.66834962e+06,
#        2.01850863e+06, 1.52692775e+06, 1.15506485e+06, 8.73764200e+05,
#        6.60970574e+05, 5.00000000e+05, 3.78231664e+05, 2.86118383e+05,
#        2.16438064e+05, 1.63727458e+05, 1.23853818e+05, 9.36908711e+04,
#        7.08737081e+04, 5.36133611e+04, 4.05565415e+04, 3.06795364e+04,
#        2.32079442e+04, 1.75559587e+04, 1.32804389e+04, 1.00461650e+04,
#        7.59955541e+03, 5.74878498e+03, 4.34874501e+03, 3.28966612e+03,
# ...

# %%
# farklı alpha (lambda) değerleri için oluşacak KATSAYI değerlerini görmek için kurulan döngü

lambdalar = 10**np.linspace(10,-2,100)*0.5 

ridge_model = Ridge()                              # model nesnesi oluşturuyoruz
katsayilar = []                                    # boş katsayılar listesi olluşturuyoruz

for i in lambdalar:
    ridge_model.set_params(alpha = i)              # her iterasyonda alpha değeri için parametreler oluşturulacak
    ridge_model.fit(X_train, y_train)              # verilen parametreler ile model fit edilecek
    katsayilar.append(ridge_model.coef_)           # modelden elde edilen katsayılar, katsayılar listesine append ediliyor
    

    
ax = plt.gca()
ax.plot(lambdalar, katsayilar) 
ax.set_xscale('log') 

plt.xlabel('Lambda(Alpha) Değerleri')
plt.ylabel('Katsayılar/Ağırlıklar')
plt.title('Düzenlileştirmenin Bir Fonksiyonu Olarak Ridge Katsayıları');

# %% [markdown]
# * lambda nın alacağı herbir değer için katsayıların alacağı değerler gözlemleniyor.
# * ridge regresyonun lambda muamemelesi katsayıları hiçbirzaman sıfır yapmamak ama tüm katsayıları modelde tutup bu katsayıların modele olan etkilerini ayarlayabilmek sıfıra yaklaştırmak mesela.
# * burada katsayılara belirlenecek lambda değerine göre öyle bir ceza uyguluyoruz ki  bu katsayılar bazen etkilerini önemlerine göre kaybetmiş oluyor. secilecek lambda değerine göre değişkenlerin görece etkilerini tahmin fonksiyonundaki etkilerini ayarlayabilmiş oluyoruz ama diyoruz ki yinede bunlar modelde kalsın sıfıra yaklaştıralım ama komple modelden çıkarmayalım demiş oluyoruz ridge kullanıldığında.

# %% [markdown]
# ## Tahmin

# %%
# test setine göre y tahmin değerleri buluyoruz lambda = 0.1 için
y_pred = ridge_model.predict(X_test)

# %%
# tahmin y değerleri ile test y değerleri MSE si bulunuyor
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 357.0239252607646

# %% [markdown]
# ## Model Tuning

# %%
lambdalar = 10**np.linspace(10,-2,100)*0.5

# %%
lambdalar[0:5]
# Out:
# array([5.00000000e+09, 3.78231664e+09, 2.86118383e+09, 2.16438064e+09,
#        1.63727458e+09])

# %%
# model nesnesi oluşturma
from sklearn.linear_model import RidgeCV
ridge_cv = RidgeCV(alphas = lambdalar, 
                   scoring = "neg_mean_squared_error",
                   normalize = True)

# %%
# model fit etme
ridge_cv.fit(X_train, y_train)
# Out:
# RidgeCV(alphas=array([5.00000000e+09, 3.78231664e+09, 2.86118383e+09, 2.16438064e+09,
#        1.63727458e+09, 1.23853818e+09, 9.36908711e+08, 7.08737081e+08,
#        5.36133611e+08, 4.05565415e+08, 3.06795364e+08, 2.32079442e+08,
#        1.75559587e+08, 1.32804389e+08, 1.00461650e+08, 7.59955541e+07,
#        5.74878498e+07, 4.34874501e+07, 3.28966612e+07, 2.48851178e+07,
#        1.88246790e+07, 1.42401793e+0...
#        1.00461650e+00, 7.59955541e-01, 5.74878498e-01, 4.34874501e-01,
#        3.28966612e-01, 2.48851178e-01, 1.88246790e-01, 1.42401793e-01,
#        1.07721735e-01, 8.14875417e-02, 6.16423370e-02, 4.66301673e-02,
#        3.52740116e-02, 2.66834962e-02, 2.01850863e-02, 1.52692775e-02,
#        1.15506485e-02, 8.73764200e-03, 6.60970574e-03, 5.00000000e-03]),
#         normalize=True, scoring='neg_mean_squared_error')

# %%
# optimum lambda değeri 
ridge_cv.alpha_
# Out:
# 0.7599555414764666

# %%
# tune edilmiş final modeli fit etme
ridge_tuned = Ridge(alpha = ridge_cv.alpha_, 
                   normalize = True).fit(X_train,y_train)

# %%
# MSE
np.sqrt(mean_squared_error(y_test, ridge_tuned.predict(X_test)))  # y_pred yerine fonksiyon yazıldı(ridge_tuned.predict(X_test))
# Out:
# 386.68264297564144

# %% [markdown]
# # Lasso Regresyon

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * ridge model ile aynı tanım geçerli, aralarındaki fark lassoda katsayıları 0 yapacak cezalar uygulanır. BU şekilde değişken seçimi yapar

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * formule dikkat edilirse Ridge formulu ile aynı sadece ceza terimi mutlak değer içerisinde, lambda ayar parametremiz yine mevcut

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Model

# %% [markdown]
# * model adımları ridge ile aynı sorun olursa ordaki kod açıklamalarına bakılabilir

# %%
hit = pd.read_csv("Hitters.csv")
df = hit.copy()
df = df.dropna()
ms = pd.get_dummies(df[['League', 'Division', 'NewLeague']])
y = df["Salary"]
X_ = df.drop(['Salary', 'League', 'Division', 'NewLeague'], axis=1).astype('float64')
X = pd.concat([X_, dms[['League_N', 'Division_W', 'NewLeague_N']]], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.25, 
                                                    random_state=42)

# %%
from sklearn.linear_model import Lasso

# %%
lasso_model = Lasso(alpha = 0.1).fit(X_train, y_train)

# %%
lasso_model
# Out:
# Lasso(alpha=0.1)

# %%
lasso_model.coef_
# Out:
# array([-1.72206506e+00,  8.56210197e+00,  6.91175137e+00, -3.13240128e+00,
#        -2.00771676e+00,  5.36159035e+00,  8.86871593e+00, -1.69520371e-01,
#        -5.58121413e-02, -3.53962588e-01,  1.70961000e+00,  6.40603469e-01,
#        -6.58519895e-01,  2.60093222e-01,  2.78717030e-01, -5.92690965e-01,
#         1.12659630e+02, -9.99652090e+01, -4.81289395e+01])

# %%
lambdalar = 10**np.linspace(10,-2,100)*0.5

lasso = Lasso()
katsayilar = []

for i in lambdalar:
    lasso.set_params(alpha=i)
    lasso.fit(X_train, y_train)
    katsayilar.append(lasso.coef_)
    
ax = plt.gca()
ax.plot(lambdalar*2, katsayilar)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('weights')
# Out:
# Text(0, 0.5, 'weights')

# %% [markdown]
# * buradaki fark şudur. ridge regresyonda lambda değerine göre katsayılar 0 a yaklaşıyordu, lasso da katsayıların bir kısmı 0 oluyor

# %% [markdown]
# ## Tahmin

# %%
lasso_model.predict(X_test)
# Out:
# array([ 613.88833029,  701.97056731, 1005.55539526,  414.08312603,
#         399.18417127,  344.71444139,  664.86990217,  451.60757   ,
#         914.64492066,  644.67006406,  691.60613554,  884.71702368,
#         210.04523766,  446.12527252,  262.94922087,  499.22332142,
#         805.2275034 ,   43.49230343, 1250.49322312,  316.34470193,
#         422.96656686,  743.29944548,  572.90774248,  655.15609074,
#         618.96407069,  200.75845796,  882.64622066,  254.06366112,
#         430.25494812,   84.17391461,  143.60312305,  130.61554   ,
#         363.74498233,  461.7321162 ,  273.42345417,  244.49816262,
#        1324.62748553,  107.89909718,  135.63065031,  242.72630885,
#          51.70024086,  297.57598929,  586.86143037,  398.85227639,
#         763.99543074,  690.10003532,  344.06272851,  247.43966241,
#         255.13234043,  662.89091837,  765.66189   ,  313.57347726,
#         765.84996179,  189.77235179,  283.98765436,  589.95238974,
# ...

# %%
y_pred = lasso_model.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 356.75452701487694

# %% [markdown]
# ## Model Tuning

# %%
from sklearn.linear_model import LassoCV

# %%
lasso_cv_model = LassoCV(alphas = None, 
                         cv = 10, 
                         max_iter = 10000, 
                         normalize = True)

# %%
lasso_cv_model.fit(X_train,y_train)
# Out:
# LassoCV(cv=10, max_iter=10000, normalize=True)

# %%
lasso_cv_model.alpha_
# Out:
# 0.3940612643247009

# %%
lasso_tuned = Lasso(alpha = lasso_cv_model.alpha_)

# %%
lasso_tuned.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.3940612643247009)

# %%
y_pred = lasso_tuned.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 356.52263769583664

# %% [markdown]
# # ElasticNet Regresyonu

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * L1 ve L2 ceza terimleri birlikte yer alıyor. BU durum daha etkili düzenleştirme yapılmasını sağlıyor.
# * EKK problemelrini ortadan kaldırır
# * En önemli yanı Ridge tarzı cezalandırma ile Lasso tarzı değişken seçmeyi bir araya getirerek aynı anda göz önünde bulunduurlmuş olmalarını sağlar. Doğrusal regresyon modellerinin en modern ve geliştirilmiş hali olarak düşünebiliriz.

# %%
hit = pd.read_csv("Hitters.csv")
df = hit.copy()
df = df.dropna()
ms = pd.get_dummies(df[['League', 'Division', 'NewLeague']])
y = df["Salary"]
X_ = df.drop(['Salary', 'League', 'Division', 'NewLeague'], axis=1).astype('float64')
X = pd.concat([X_, dms[['League_N', 'Division_W', 'NewLeague_N']]], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.25, 
                                                    random_state=42)

# %%
from sklearn.linear_model import ElasticNet

# %%
enet_model = ElasticNet().fit(X_train, y_train)

# %%
enet_model.coef_
# Out:
# array([ -1.86256172,   8.70489065,   5.10426375,  -2.89875799,
#         -1.28642985,   5.24343682,   6.04480276,  -0.14701495,
#         -0.21566628,  -0.7897201 ,   1.80813117,   0.80914508,
#         -0.61262382,   0.26816203,   0.27172387,  -0.36530729,
#         19.2186222 , -31.16586592,   8.98369938])

# %%
enet_model.intercept_
# Out:
# -6.465955602114036

# %% [markdown]
# ## Tahmin

# %%
enet_model
# Out:
# ElasticNet()

# %%
enet_model.predict(X_test)
# Out:
# array([ 577.79111731,  617.33202224, 1031.39113156,  364.95861575,
#         489.51894393,  300.74185842,  604.522666  ,  465.34678732,
#         901.44473965,  703.20357123,  702.9157117 ,  931.50283407,
#         184.87939803,  385.14973787,  325.38944176,  546.99346574,
#         774.28001821,  101.83114992, 1250.86758812,  370.67651244,
#         442.05734523,  781.17288513,  578.63736538,  609.31927808,
#         608.31719597,  227.46556223,  921.85505228,  301.1202457 ,
#         386.31721051,  133.61143326,  162.28505608,   88.29793182,
#         359.9068418 ,  422.51268445,  265.8663769 ,  355.70450908,
#        1329.36312363,  125.05506935,   82.74580002,  269.17483075,
#         117.13319397,  274.13484779,  648.4957249 ,  409.47065999,
#         846.27919406,  712.04817644,  341.10596674,  368.24259678,
#         305.70477656,  680.05724792,  716.13640636,  295.93204262,
#         773.06445823,  249.28224916,  221.46794589,  541.2713245 ,
# ...

# %%
y_pred = enet_model.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 357.1676548181248

# %%
r2_score(y_test, y_pred)
# Out:
# 0.410702224693268

# %% [markdown]
# ## Model Tuning

# %%
from sklearn.linear_model import ElasticNetCV

# %%
enet_cv_model = ElasticNetCV(cv = 10, random_state = 0).fit(X_train, y_train)

# %%
enet_cv_model.alpha_
# Out:
# 5230.7647364798695

# %%
enet_cv_model
# Out:
# ElasticNetCV(cv=10, random_state=0)

# %%
enet_tuned = ElasticNet(alpha = enet_cv_model.alpha_).fit(X_train,y_train)

# %%
y_pred = enet_tuned.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 394.15280563218795

# %% [markdown]
# Ridge Lasso ve Enet modelleri sonunda baktığımızda MSE si en düşük olan Lasso çıkmıştır

# %% [markdown]
# ![image.png](attachment:image.png)
